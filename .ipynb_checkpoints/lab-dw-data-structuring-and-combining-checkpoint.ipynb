# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# %%
def column_cleaner(df):
    new_cols = [col.lower().rstrip().replace(" ","_") for col in df.columns]
    new_cols[1] = 'state'
    df.columns = new_cols

def drop_na(df):
    df = df.dropna(how='all')
    
def gender_cleaner(df):
    df.gender = df.gender.replace(to_replace = ["female","Femal"], value = "F")
    df.gender = df.gender.replace(to_replace = ["Male"], value = "M")
    df.gender = df.gender.fillna("NA")

def complaint_cleaner(df):
    df["number_of_open_complaints"] = df["number_of_open_complaints"].astype('str')
    df["number_of_open_complaints"] = df["number_of_open_complaints"].apply(lambda x: x[2])
    df["number_of_open_complaints"] = df["number_of_open_complaints"].replace(to_replace = "n", value = "NaN")
    df["number_of_open_complaints"] = df["number_of_open_complaints"].astype('float64')

def state_cleaner(df):
    df.state = df.state.replace(to_replace = ["AZ", "WA", "Cali"], value = ["Arizona", "Washington", "California"])

def clv_cleaner(df):
    df.customer_lifetime_value = df.customer_lifetime_value.astype('str')
    df['customer_lifetime_value'] = df['customer_lifetime_value'].str.rstrip('%')
    df.customer_lifetime_value = df.customer_lifetime_value.astype('float64')
    # df.customer_lifetime_value = df.customer_lifetime_value.fillna(df.customer_lifetime_value.mean())

def vehicle_cleaner(df):
    df.vehicle_class = df.vehicle_class.replace(to_replace = ["Sports Car", "Luxury SUV", "Luxury Car"], value = "Luxury")

def education_cleaner(df):
    df.education = df.education.replace(to_replace = "Bachelors", value = "Bachelor")

# def float_to_int(df):
#     for elem in df.columns:
#         if df[elem].dtype == 'float64':
#             df[elem] = df[elem].round(0).astype('int64')   

def customer_cleaner(df):
    column_cleaner(df)
    drop_na(df)
    gender_cleaner(df)
    complaint_cleaner(df)
    state_cleaner(df)
    clv_cleaner(df)
    vehicle_cleaner(df)
    education_cleaner(df)
    # float_to_int(df)
    return df

# %%
column_cleaner(df1)

# %%
df1 = df1.dropna(how = 'all')
df1_clean = customer_cleaner(df1)

# df1_clean = df1_clean.drop(df1.tail(2937).index)
display(df1_clean)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington     NA                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
df2_clean = customer_cleaner(df2)
# df2_clean = df2_clean.drop(df2.tail(2937).index)
display(df2_clean)
# Out:
#     customer       state gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
df3.vehicle_class = df3.vehicle_class.replace(to_replace = ["Sports Car", "Luxury SUV", "Luxury Car"], value = "Luxury")
df3_clean = df3

# %%
df_all = pd.concat([df1_clean,df2_clean,df3_clean])
display(df_all)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington     NA                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
df_mca = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')
display(df_mca)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
df_mca.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month', 'yearly_premium_auto'],
#       dtype='object')

# %%
df_mca['monthly_premium_auto'].value_counts()
# Out:
# monthly_premium_auto
# 65     419
# 66     371
# 71     368
# 73     363
# 63     345
#       ...
# 163      1
# 178      1
# 287      1
# 228      1
# 203      1
# Name: count, Length: 202, dtype: int64

# %%
grouped = df_mca.groupby('sales_channel')
df_mca['yearly_premium_auto'] = df_mca['monthly_premium_auto'].apply(lambda x: x*12)
grouped['yearly_premium_auto'].sum().round(2)
# Out:
# sales_channel
# Agent          4636020
# Branch         3371436
# Call Center    2375640
# Web            1818132
# Name: yearly_premium_auto, dtype: int64

# %%
grouped['number_of_policies'].sum().round(2)
# Out:
# sales_channel
# Agent          12227
# Branch          8814
# Call Center     6462
# Web             5000
# Name: number_of_policies, dtype: int64

# %%
df_mca.pivot_table(index = 'sales_channel', columns = ['policy_type'], values = 'yearly_premium_auto', aggfunc = 'sum')
# Out:
# policy_type    Corporate Auto  Personal Auto  Special Auto
# sales_channel
# Agent                  994236        3440700        201084
# Branch                 726780        2502936        141720
# Call Center            515364        1791432         68844
# Web                    377760        1357776         82596

# %%
df_mca['avg_policy_premium_yr'] = df_mca['yearly_premium_auto'] / df_mca['number_of_policies']

# %%
pd.Series(grouped_2['avg_policy_premium_yr'].mean())
# Out:
# sales_channel  policy_type
# Agent          Corporate Auto    611.300985
#                Personal Auto     653.689855
#                Special Auto      686.772702
# Branch         Corporate Auto    638.793970
#                Personal Auto     640.779458
#                Special Auto      653.352455
# Call Center    Corporate Auto    629.343459
#                Personal Auto     621.272688
#                Special Auto      571.070522
# Web            Corporate Auto    623.763321
#                Personal Auto     633.044792
#                Special Auto      594.776562
# Name: avg_policy_premium_yr, dtype: float64

# %%
df2
# Out:
#     avg_policy_premium_yr
# 0                  611.30
# 1                  653.69
# 2                  686.77
# 3                  638.79
# 4                  640.78
# 5                  653.35
# 6                  629.34
# 7                  621.27
# 8                  571.07
# 9                  623.76
# 10                 633.04
# 11                 594.78

# %%
grouped_2 = df_mca.groupby(['sales_channel','policy_type'])
df1 = pd.DataFrame(grouped_2[['yearly_premium_auto','number_of_policies']].sum().round(2)).reset_index()
df2 = pd.DataFrame(grouped_2['avg_policy_premium_yr'].mean()).reset_index(drop=True).round(2)
df3 = (pd.concat([df1,df2], axis = 1))
#df3.sort_values(by = 'number_of_policies', axis=0, ascending = False).reset_index(drop = True)
df3.sort_values(by = 'avg_policy_premium_yr', axis=0, ascending = False).reset_index(drop = True)
# Out:
#    sales_channel     policy_type  yearly_premium_auto  number_of_policies  \
# 0          Agent    Special Auto               201084                 467
# 1          Agent   Personal Auto              3440700                8954
# 2         Branch    Special Auto               141720                 360
# 3         Branch   Personal Auto              2502936                6574
# 4         Branch  Corporate Auto               726780                1880
# 5            Web   Personal Auto              1357776                3654
# 6    Call Center  Corporate Auto               515364                1372
# 7            Web  Corporate Auto               377760                1128
# 8    Call Center   Personal Auto              1791432                4892
# 9          Agent  Corporate Auto               994236                2806
# 10           Web    Special Auto                82596                 218
# 11   Call Center    Special Auto                68844                 198
#
# ...

# %%
# Premiums sold in branch are consistently high, with the three types of policy coming in the top 5 average annual premiums. 
# Agents bring in the highest yearly premiums, in line with them selling the highest number of policies.
# Agents also bring in the highest average annual premiums 
# Call Centers generally bring in the lowest premiums on average, though web accounts for the lowest numbers of policies sold.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
grouped_3 = df_mca.groupby(['gender','education'])

# %%
grouped_3 = df_mca.groupby(['gender','education'])
mean_values = grouped_3['customer_lifetime_value'].mean()

# Sort the values within each gender
sorted_values = mean_values.groupby(level=0, group_keys=False).apply(lambda x: x.sort_values(ascending=False))

print(sorted_values)
# Out:
# gender  education
# F       High School or Below    8675.220201
#         Master                  8157.053154
#         Bachelor                7874.269478
#         College                 7748.823325
#         Doctor                  7328.508916
# M       Master                  8168.832659
#         High School or Below    8149.687783
#         College                 8052.459288
#         Bachelor                7703.601675
#         Doctor                  7415.333638
# Name: customer_lifetime_value, dtype: float64

# %%
grouped_3 = df_mca.groupby(['gender','education'])
sorted_df = (df_mca.groupby(['gender','education'])['customer_lifetime_value'].mean().to_frame('mean_clv').reset_index().sort_values(['gender', 'mean_clv'], ascending=[True, False]))
sorted_df
# Out:
#   gender             education     mean_clv
# 3      F  High School or Below  8675.220201
# 4      F                Master  8157.053154
# 0      F              Bachelor  7874.269478
# 1      F               College  7748.823325
# 2      F                Doctor  7328.508916
# 9      M                Master  8168.832659
# 8      M  High School or Below  8149.687783
# 6      M               College  8052.459288
# 5      M              Bachelor  7703.601675
# 7      M                Doctor  7415.333638

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
